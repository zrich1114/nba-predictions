# %% [markdown]
# ## Today's Score Board

# %%
from datetime import datetime, timezone
from dateutil import parser
from nba_api.live.nba.endpoints import scoreboard

f = "{gameId}: {awayTeam} vs {homeTeam} @ {gameTimeLTZ}"

board = scoreboard.ScoreBoard()
print("ScoreboardDate: " + board.score_board_date)
games = board.games.get_dict()
for game in games:
  gameTimeLTZ = parser.parse(game["gameTimeUTC"]).replace(tzinfo=timezone.utc).astimezone(tz=None)
  print(f.format(gameId=game['gameId'], awayTeam=game['awayTeam']['teamName'], homeTeam=game['homeTeam']['teamName'], gameTimeLTZ=gameTimeLTZ))
# Out:
# ScoreboardDate: 2024-06-01

# %% [markdown]
# ## Box Score

# %%
# Get Box Score
from nba_api.live.nba.endpoints import boxscore
box = boxscore.BoxScore('0022000196')

# %%
# Data Sets
box.game.get_dict()
#box.arena.get_dict()                  #equal to box.get_dict()['game']['arena']
#box.away_team.get_dict()              #equal to box.get_dict()['game']['awayTeam']
#box.away_team_player_stats.get_dict() #equal to box.get_dict()['game']['awayTeam']['players']
#box.away_team_stats.get_dict()        #equal to box.get_dict()['game']['homeTeam'] w/o ['players']
#box.home_team.get_dict()              #equal to box.get_dict()['game']['homeTeam']
#box.home_team_player_stats.get_dict() #equal to box.get_dict()['game']['homeTeam']['players']
#box.home_team_stats.get_dict()        #equal to box.get_dict()['game']['homeTeam'] w/o ['players']
#box.game_details.get_dict()           #equal to box.get_dict()['game'] scrubbed of all other dictionaries
#box.officials.get_dict()              #equal to box.get_dict()['game']['officials']
# Out:
# {'gameId': '0022000196',
#  'gameTimeLocal': '2021-01-17T13:00:00-05:00',
#  'gameTimeUTC': '2021-01-17T18:00:00Z',
#  'gameTimeHome': '2021-01-17T13:00:00-05:00',
#  'gameTimeAway': '2021-01-17T13:00:00-05:00',
#  'gameEt': '2021-01-17T13:00:00-05:00',
#  'duration': 134,
#  'gameCode': '20210117/NYKBOS',
#  'gameStatusText': 'Final',
#  'gameStatus': 3,
#  'regulationPeriods': 4,
#  'period': 4,
#  'gameClock': 'PT00M00.00S',
#  'attendance': 0,
#  'sellout': '0',
#  'arena': {'arenaId': 17,
#   'arenaName': 'TD Garden',
#   'arenaCity': 'Boston',
#   'arenaState': 'MA',
#   'arenaCountry': 'US',
#   'arenaTimezone': 'America/New_York'},
#  'officials': [{'personId': 2882,
#    'name': 'Sean Wright',
#    'nameI': 'S. Wright',
#    'firstName': 'Sean',
#    'familyName': 'Wright',
#    'jerseyNum': '4',
#    'assignment': 'OFFICIAL1'},
#   {'personId': 201638,
#    'name': 'Brent Barnaky',
#    'nameI': 'B. Barnaky',
#    'firstName': 'Brent',
#    'familyName': 'Barnaky',
#    'jerseyNum': '36',
#    'assignment': 'OFFICIAL2'},
#   {'personId': 1627524,
#    'name': 'Nate Green',
#    'nameI': 'N. Green',
#    'firstName': 'Nate',
#    'familyName': 'Green',
#    'jerseyNum': '65',
#    'assignment': 'OFFICIAL3'}],
#  'homeTeam': {'teamId': 1610612738,
#   'teamName': 'Celtics',
#   'teamCity': 'Boston',
#   'teamTricode': 'BOS',
#   'score': 75,
#   'inBonus': '1',
#   'timeoutsRemaining': 2,
#   'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 17},
#    {'period': 2, 'periodType': 'REGULAR', 'score': 18},
#    {'period': 3, 'periodType': 'REGULAR', 'score': 15},
#    {'period': 4, 'periodType': 'REGULAR', 'score': 25}],
#   'players': [{'status': 'ACTIVE',
#     'order': 1,
#     'personId': 1627759,
#     'jerseyNum': '7',
#     'position': 'SF',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 3,
#      'blocks': 0,
#      'blocksReceived': 2,
#      'fieldGoalsAttempted': 20,
#      'fieldGoalsMade': 9,
#      'fieldGoalsPercentage': 0.45,
#      'foulsOffensive': 0,
#      'foulsDrawn': 5,
#      'foulsPersonal': 3,
#      'foulsTechnical': 1,
#      'freeThrowsAttempted': 5,
#      'freeThrowsMade': 4,
#      'freeThrowsPercentage': 0.8,
#      'minus': 73.0,
#      'minutes': 'PT32M33.00S',
#      'minutesCalculated': 'PT33M',
#      'plus': 46.0,
#      'plusMinusPoints': -27.0,
#      'points': 25,
#      'pointsFastBreak': 7,
#      'pointsInThePaint': 8,
#      'pointsSecondChance': 4,
#      'reboundsDefensive': 3,
#      'reboundsOffensive': 3,
#      'reboundsTotal': 6,
#      'steals': 1,
#      'threePointersAttempted': 9,
#      'threePointersMade': 3,
#      'threePointersPercentage': 0.333333333333333,
#      'turnovers': 2,
#      'twoPointersAttempted': 11,
#      'twoPointersMade': 6,
#      'twoPointersPercentage': 0.545454545454545},
#     'name': 'Jaylen Brown',
#     'nameI': 'J. Brown',
#     'firstName': 'Jaylen',
#     'familyName': 'Brown'},
#    {'status': 'ACTIVE',
#     'order': 2,
#     'personId': 1629684,
#     'jerseyNum': '12',
#     'position': 'PF',
#     'starter': '1',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 5,
#      'fieldGoalsMade': 1,
#      'fieldGoalsPercentage': 0.2,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 5,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 4,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 0.25,
#      'minus': 59.0,
#      'minutes': 'PT24M25.00S',
#      'minutesCalculated': 'PT24M',
#      'plus': 41.0,
#      'plusMinusPoints': -18.0,
#      'points': 3,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 2,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 2,
#      'steals': 1,
#      'threePointersAttempted': 4,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 1,
#      'twoPointersAttempted': 1,
#      'twoPointersMade': 1,
#      'twoPointersPercentage': 1.0},
#     'name': 'Grant Williams',
#     'nameI': 'G. Williams',
#     'firstName': 'Grant',
#     'familyName': 'Williams'},
#    {'status': 'ACTIVE',
#     'order': 3,
#     'personId': 202684,
#     'jerseyNum': '13',
#     'position': 'C',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 1,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 5,
#      'fieldGoalsMade': 1,
#      'fieldGoalsPercentage': 0.2,
#      'foulsOffensive': 1,
#      'foulsDrawn': 3,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 0.5,
#      'minus': 54.0,
#      'minutes': 'PT26M12.04S',
#      'minutesCalculated': 'PT26M',
#      'plus': 36.0,
#      'plusMinusPoints': -18.0,
#      'points': 3,
#      'pointsFastBreak': 1,
#      'pointsInThePaint': 2,
#      'pointsSecondChance': 1,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 5,
#      'reboundsTotal': 6,
#      'steals': 1,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 2,
#      'twoPointersAttempted': 5,
#      'twoPointersMade': 1,
#      'twoPointersPercentage': 0.2},
#     'name': 'Tristan Thompson',
#     'nameI': 'T. Thompson',
#     'firstName': 'Tristan',
#     'familyName': 'Thompson'},
#    {'status': 'ACTIVE',
#     'order': 4,
#     'personId': 203935,
#     'jerseyNum': '36',
#     'position': 'SG',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 2,
#      'blocks': 0,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 15,
#      'fieldGoalsMade': 4,
#      'fieldGoalsPercentage': 0.266666666666667,
#      'foulsOffensive': 0,
#      'foulsDrawn': 6,
#      'foulsPersonal': 3,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 5,
#      'freeThrowsMade': 2,
#      'freeThrowsPercentage': 0.4,
#      'minus': 64.0,
#      'minutes': 'PT29M22.00S',
#      'minutesCalculated': 'PT29M',
#      'plus': 42.0,
#      'plusMinusPoints': -22.0,
#      'points': 10,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 8,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 2,
#      'steals': 2,
#      'threePointersAttempted': 7,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 8,
#      'twoPointersMade': 4,
#      'twoPointersPercentage': 0.5},
#     'name': 'Marcus Smart',
#     'nameI': 'M. Smart',
#     'firstName': 'Marcus',
#     'familyName': 'Smart'},
#    {'status': 'ACTIVE',
#     'order': 5,
#     'personId': 202689,
#     'jerseyNum': '8',
#     'position': 'PG',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 4,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 13,
#      'fieldGoalsMade': 3,
#      'fieldGoalsPercentage': 0.230769230769231,
#      'foulsOffensive': 0,
#      'foulsDrawn': 4,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 3,
#      'freeThrowsMade': 2,
#      'freeThrowsPercentage': 0.666666666666666,
#      'minus': 36.0,
#      'minutes': 'PT19M37.00S',
#      'minutesCalculated': 'PT20M',
#      'plus': 27.0,
#      'plusMinusPoints': -9.0,
#      'points': 9,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 4,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 3,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 3,
#      'steals': 3,
#      'threePointersAttempted': 8,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.125,
#      'turnovers': 5,
#      'twoPointersAttempted': 5,
#      'twoPointersMade': 2,
#      'twoPointersPercentage': 0.4},
#     'name': 'Kemba Walker',
#     'nameI': 'K. Walker',
#     'firstName': 'Kemba',
#     'familyName': 'Walker'},
#    {'status': 'ACTIVE',
#     'order': 6,
#     'personId': 201952,
#     'jerseyNum': '55',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 2,
#      'blocks': 0,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 4,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 40.0,
#      'minutes': 'PT14M28.00S',
#      'minutesCalculated': 'PT15M',
#      'plus': 25.0,
#      'plusMinusPoints': -15.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 2,
#      'steals': 1,
#      'threePointersAttempted': 2,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 1,
#      'twoPointersAttempted': 2,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Jeff Teague',
#     'nameI': 'J. Teague',
#     'firstName': 'Jeff',
#     'familyName': 'Teague'},
#    {'status': 'ACTIVE',
#     'order': 7,
#     'personId': 1628464,
#     'jerseyNum': '27',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 4,
#      'fieldGoalsMade': 3,
#      'fieldGoalsPercentage': 0.75,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 3,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 39.0,
#      'minutes': 'PT19M49.00S',
#      'minutesCalculated': 'PT20M',
#      'plus': 32.0,
#      'plusMinusPoints': -7.0,
#      'points': 7,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 4,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 6,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 7,
#      'steals': 0,
#      'threePointersAttempted': 2,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.5,
#      'turnovers': 2,
#      'twoPointersAttempted': 2,
#      'twoPointersMade': 2,
#      'twoPointersPercentage': 1.0},
#     'name': 'Daniel Theis',
#     'nameI': 'D. Theis',
#     'firstName': 'Daniel',
#     'familyName': 'Theis'},
#    {'status': 'ACTIVE',
#     'order': 8,
#     'personId': 1628400,
#     'jerseyNum': '37',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 6,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 1,
#      'foulsDrawn': 3,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 4,
#      'freeThrowsMade': 4,
#      'freeThrowsPercentage': 1.0,
#      'minus': 48.0,
#      'minutes': 'PT23M22.00S',
#      'minutesCalculated': 'PT23M',
#      'plus': 39.0,
#      'plusMinusPoints': -9.0,
#      'points': 4,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 3,
#      'steals': 0,
#      'threePointersAttempted': 6,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 1,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Semi Ojeleye',
#     'nameI': 'S. Ojeleye',
#     'firstName': 'Semi',
#     'familyName': 'Ojeleye'},
#    {'status': 'ACTIVE',
#     'order': 9,
#     'personId': 1630202,
#     'jerseyNum': '11',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 1,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 3,
#      'fieldGoalsMade': 1,
#      'fieldGoalsPercentage': 0.333333333333333,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 32.0,
#      'minutes': 'PT17M22.96S',
#      'minutesCalculated': 'PT17M',
#      'plus': 28.0,
#      'plusMinusPoints': -4.0,
#      'points': 3,
#      'pointsFastBreak': 3,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 4,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 5,
#      'steals': 0,
#      'threePointersAttempted': 3,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.333333333333333,
#      'turnovers': 2,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Payton Pritchard',
#     'nameI': 'P. Pritchard',
#     'firstName': 'Payton',
#     'familyName': 'Pritchard'},
#    {'status': 'ACTIVE',
#     'order': 10,
#     'personId': 1629750,
#     'jerseyNum': '43',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 3,
#      'fieldGoalsMade': 2,
#      'fieldGoalsPercentage': 0.666666666666666,
#      'foulsOffensive': 0,
#      'foulsDrawn': 3,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 6,
#      'freeThrowsMade': 4,
#      'freeThrowsPercentage': 0.666666666666666,
#      'minus': 39.0,
#      'minutes': 'PT17M50.00S',
#      'minutesCalculated': 'PT18M',
#      'plus': 29.0,
#      'plusMinusPoints': -10.0,
#      'points': 8,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 4,
#      'pointsSecondChance': 1,
#      'reboundsDefensive': 3,
#      'reboundsOffensive': 2,
#      'reboundsTotal': 5,
#      'steals': 0,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 1,
#      'twoPointersAttempted': 2,
#      'twoPointersMade': 2,
#      'twoPointersPercentage': 1.0},
#     'name': 'Javonte Green',
#     'nameI': 'J. Green',
#     'firstName': 'Javonte',
#     'familyName': 'Green'},
#    {'status': 'ACTIVE',
#     'order': 11,
#     'personId': 1630174,
#     'jerseyNum': '26',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 2,
#      'fieldGoalsAttempted': 4,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 23.0,
#      'minutes': 'PT08M26.00S',
#      'minutesCalculated': 'PT08M',
#      'plus': 17.0,
#      'plusMinusPoints': -6.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 1,
#      'steals': 0,
#      'threePointersAttempted': 2,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 2,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Aaron Nesmith',
#     'nameI': 'A. Nesmith',
#     'firstName': 'Aaron',
#     'familyName': 'Nesmith'},
#    {'status': 'ACTIVE',
#     'order': 12,
#     'personId': 1629682,
#     'jerseyNum': '51',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 2,
#      'fieldGoalsMade': 1,
#      'fieldGoalsPercentage': 0.5,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 18.0,
#      'minutes': 'PT06M33.00S',
#      'minutesCalculated': 'PT07M',
#      'plus': 13.0,
#      'plusMinusPoints': -5.0,
#      'points': 3,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 1,
#      'steals': 1,
#      'threePointersAttempted': 2,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.5,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Tremont Waters',
#     'nameI': 'T. Waters',
#     'firstName': 'Tremont',
#     'familyName': 'Waters'},
#    {'status': 'INACTIVE',
#     'notPlayingReason': 'INACTIVE_HEALTH_AND_SAFETY_PROTOCOLS',
#     'order': 13,
#     'personId': 1629035,
#     'jerseyNum': '4',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Carsen Edwards',
#     'nameI': 'C. Edwards',
#     'firstName': 'Carsen',
#     'familyName': 'Edwards'},
#    {'status': 'INACTIVE',
#     'notPlayingReason': 'INACTIVE_INJURY',
#     'notPlayingDescription': 'Left Ankle; Sprain',
#     'order': 14,
#     'personId': 1629605,
#     'jerseyNum': '99',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Tacko Fall',
#     'nameI': 'T. Fall',
#     'firstName': 'Tacko',
#     'familyName': 'Fall'},
#    {'status': 'INACTIVE',
#     'notPlayingReason': 'INACTIVE_INJURY',
#     'notPlayingDescription': 'Right Wrist; Surgery',
#     'order': 15,
#     'personId': 1629641,
#     'jerseyNum': '45',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Romeo Langford',
#     'nameI': 'R. Langford',
#     'firstName': 'Romeo',
#     'familyName': 'Langford'},
#    {'status': 'INACTIVE',
#     'notPlayingReason': 'INACTIVE_HEALTH_AND_SAFETY_PROTOCOLS',
#     'order': 16,
#     'personId': 1628369,
#     'jerseyNum': '0',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Jayson Tatum',
#     'nameI': 'J. Tatum',
#     'firstName': 'Jayson',
#     'familyName': 'Tatum'},
#    {'status': 'INACTIVE',
#     'notPlayingReason': 'INACTIVE_HEALTH_AND_SAFETY_PROTOCOLS',
#     'order': 17,
#     'personId': 1629057,
#     'jerseyNum': '44',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Robert Williams III',
#     'nameI': 'R. Williams III',
#     'firstName': 'Robert',
#     'familyName': 'Williams III'}],
#   'statistics': {'assists': 15,
#    'assistsTurnoverRatio': 0.833333333333334,
#    'benchPoints': 25,
#    'biggestLead': 0,
#    'biggestScoringRun': 9,
#    'biggestScoringRunScore': '44-29',
#    'blocks': 2,
#    'blocksReceived': 7,
#    'fastBreakPointsAttempted': 8,
#    'fastBreakPointsMade': 4,
#    'fastBreakPointsPercentage': 0.5,
#    'fieldGoalsAttempted': 84,
#    'fieldGoalsEffectiveAdjusted': 0.339285714285714,
#    'fieldGoalsMade': 25,
#    'fieldGoalsPercentage': 0.297619047619048,
#    'foulsOffensive': 2,
#    'foulsDrawn': 28,
#    'foulsPersonal': 22,
#    'foulsTeam': 20,
#    'foulsTechnical': 1,
#    'foulsTeamTechnical': 0,
#    'freeThrowsAttempted': 29,
#    'freeThrowsMade': 18,
#    'freeThrowsPercentage': 0.620689655172414,
#    'leadChanges': 0,
#    'minutes': 'PT240M00.00S',
#    'minutesCalculated': 'PT240M',
#    'points': 75,
#    'pointsAgainst': 105,
#    'pointsFastBreak': 11,
#    'pointsFromTurnovers': 11,
#    'pointsInThePaint': 32,
#    'pointsInThePaintAttempted': 32,
#    'pointsInThePaintMade': 16,
#    'pointsInThePaintPercentage': 0.5,
#    'pointsSecondChance': 6,
#    'reboundsDefensive': 29,
#    'reboundsOffensive': 14,
#    'reboundsPersonal': 43,
#    'reboundsTeam': 10,
#    'reboundsTeamDefensive': 3,
#    'reboundsTeamOffensive': 7,
#    'reboundsTotal': 53,
#    'secondChancePointsAttempted': 11,
#    'secondChancePointsMade': 1,
#    'secondChancePointsPercentage': 0.0909090909090909,
#    'steals': 10,
#    'threePointersAttempted': 46,
#    'threePointersMade': 7,
#    'threePointersPercentage': 0.152173913043478,
#    'timeLeading': 'PT00M00.00S',
#    'timesTied': 1,
#    'trueShootingAttempts': 96.76,
#    'trueShootingPercentage': 0.38755684167011195,
#    'turnovers': 17,
#    'turnoversTeam': 1,
#    'turnoversTotal': 18,
#    'twoPointersAttempted': 38,
#    'twoPointersMade': 18,
#    'twoPointersPercentage': 0.473684210526316}},
#  'awayTeam': {'teamId': 1610612752,
#   'teamName': 'Knicks',
#   'teamCity': 'New York',
#   'teamTricode': 'NYK',
#   'score': 105,
#   'inBonus': '1',
#   'timeoutsRemaining': 2,
#   'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 28},
#    {'period': 2, 'periodType': 'REGULAR', 'score': 20},
#    {'period': 3, 'periodType': 'REGULAR', 'score': 27},
#    {'period': 4, 'periodType': 'REGULAR', 'score': 30}],
#   'players': [{'status': 'ACTIVE',
#     'order': 1,
#     'personId': 203493,
#     'jerseyNum': '25',
#     'position': 'SF',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 9,
#      'fieldGoalsMade': 4,
#      'fieldGoalsPercentage': 0.444444444444444,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 34.0,
#      'minutes': 'PT28M10.00S',
#      'minutesCalculated': 'PT28M',
#      'plus': 70.0,
#      'plusMinusPoints': 36.0,
#      'points': 11,
#      'pointsFastBreak': 3,
#      'pointsInThePaint': 2,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 6,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 7,
#      'steals': 1,
#      'threePointersAttempted': 8,
#      'threePointersMade': 3,
#      'threePointersPercentage': 0.375,
#      'turnovers': 1,
#      'twoPointersAttempted': 1,
#      'twoPointersMade': 1,
#      'twoPointersPercentage': 1.0},
#     'name': 'Reggie Bullock',
#     'nameI': 'R. Bullock',
#     'firstName': 'Reggie',
#     'familyName': 'Bullock'},
#    {'status': 'ACTIVE',
#     'order': 2,
#     'personId': 203944,
#     'jerseyNum': '30',
#     'position': 'PF',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 4,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 14,
#      'fieldGoalsMade': 7,
#      'fieldGoalsPercentage': 0.5,
#      'foulsOffensive': 1,
#      'foulsDrawn': 5,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 5,
#      'freeThrowsMade': 4,
#      'freeThrowsPercentage': 0.8,
#      'minus': 43.0,
#      'minutes': 'PT31M03.00S',
#      'minutesCalculated': 'PT31M',
#      'plus': 72.0,
#      'plusMinusPoints': 29.0,
#      'points': 20,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 8,
#      'pointsSecondChance': 7,
#      'reboundsDefensive': 12,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 12,
#      'steals': 3,
#      'threePointersAttempted': 5,
#      'threePointersMade': 2,
#      'threePointersPercentage': 0.4,
#      'turnovers': 3,
#      'twoPointersAttempted': 9,
#      'twoPointersMade': 5,
#      'twoPointersPercentage': 0.555555555555556},
#     'name': 'Julius Randle',
#     'nameI': 'J. Randle',
#     'firstName': 'Julius',
#     'familyName': 'Randle'},
#    {'status': 'ACTIVE',
#     'order': 3,
#     'personId': 1629011,
#     'jerseyNum': '23',
#     'position': 'C',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 2,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 5,
#      'fieldGoalsMade': 4,
#      'fieldGoalsPercentage': 0.8,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 4,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 30.0,
#      'minutes': 'PT24M12.97S',
#      'minutesCalculated': 'PT24M',
#      'plus': 58.0,
#      'plusMinusPoints': 28.0,
#      'points': 8,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 8,
#      'pointsSecondChance': 4,
#      'reboundsDefensive': 3,
#      'reboundsOffensive': 4,
#      'reboundsTotal': 7,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 1,
#      'twoPointersAttempted': 5,
#      'twoPointersMade': 4,
#      'twoPointersPercentage': 0.8},
#     'name': 'Mitchell Robinson',
#     'nameI': 'M. Robinson',
#     'firstName': 'Mitchell',
#     'familyName': 'Robinson'},
#    {'status': 'ACTIVE',
#     'order': 4,
#     'personId': 1629628,
#     'jerseyNum': '9',
#     'position': 'SG',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 3,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 11,
#      'fieldGoalsMade': 5,
#      'fieldGoalsPercentage': 0.45454545454545503,
#      'foulsOffensive': 1,
#      'foulsDrawn': 6,
#      'foulsPersonal': 3,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 8,
#      'freeThrowsMade': 7,
#      'freeThrowsPercentage': 0.875,
#      'minus': 40.0,
#      'minutes': 'PT29M14.00S',
#      'minutesCalculated': 'PT29M',
#      'plus': 72.0,
#      'plusMinusPoints': 32.0,
#      'points': 19,
#      'pointsFastBreak': 2,
#      'pointsInThePaint': 6,
#      'pointsSecondChance': 6,
#      'reboundsDefensive': 7,
#      'reboundsOffensive': 4,
#      'reboundsTotal': 11,
#      'steals': 2,
#      'threePointersAttempted': 4,
#      'threePointersMade': 2,
#      'threePointersPercentage': 0.5,
#      'turnovers': 4,
#      'twoPointersAttempted': 7,
#      'twoPointersMade': 3,
#      'twoPointersPercentage': 0.428571428571429},
#     'name': 'RJ Barrett',
#     'nameI': 'R. Barrett',
#     'firstName': 'RJ',
#     'familyName': 'Barrett'},
#    {'status': 'ACTIVE',
#     'order': 5,
#     'personId': 203901,
#     'jerseyNum': '6',
#     'position': 'PG',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 3,
#      'blocks': 1,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 9,
#      'fieldGoalsMade': 3,
#      'fieldGoalsPercentage': 0.333333333333333,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 3,
#      'freeThrowsMade': 3,
#      'freeThrowsPercentage': 1.0,
#      'minus': 34.0,
#      'minutes': 'PT23M10.00S',
#      'minutesCalculated': 'PT23M',
#      'plus': 49.0,
#      'plusMinusPoints': 15.0,
#      'points': 9,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 4,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 3,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 4,
#      'steals': 1,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 2,
#      'twoPointersAttempted': 8,
#      'twoPointersMade': 3,
#      'twoPointersPercentage': 0.375},
#     'name': 'Elfrid Payton',
#     'nameI': 'E. Payton',
#     'firstName': 'Elfrid',
#     'familyName': 'Payton'},
#    {'status': 'ACTIVE',
#     'order': 6,
#     'personId': 203457,
#     'jerseyNum': '3',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 2,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 3,
#      'fieldGoalsMade': 2,
#      'fieldGoalsPercentage': 0.666666666666666,
#      'foulsOffensive': 0,
#      'foulsDrawn': 3,
#      'foulsPersonal': 4,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 0.5,
#      'minus': 45.0,
#      'minutes': 'PT23M47.03S',
#      'minutesCalculated': 'PT24M',
#      'plus': 47.0,
#      'plusMinusPoints': 2.0,
#      'points': 5,
#      'pointsFastBreak': 2,
#      'pointsInThePaint': 4,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 4,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 4,
#      'steals': 2,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 3,
#      'twoPointersMade': 2,
#      'twoPointersPercentage': 0.666666666666666},
#     'name': 'Nerlens Noel',
#     'nameI': 'N. Noel',
#     'firstName': 'Nerlens',
#     'familyName': 'Noel'},
#    {'status': 'ACTIVE',
#     'order': 7,
#     'personId': 203085,
#     'jerseyNum': '8',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 2,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 3,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 1,
#      'foulsDrawn': 1,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 32.0,
#      'minutes': 'PT16M19.00S',
#      'minutesCalculated': 'PT16M',
#      'plus': 32.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 1,
#      'steals': 0,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 1,
#      'twoPointersAttempted': 2,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Austin Rivers',
#     'nameI': 'A. Rivers',
#     'firstName': 'Austin',
#     'familyName': 'Rivers'},
#    {'status': 'ACTIVE',
#     'order': 8,
#     'personId': 1630193,
#     'jerseyNum': '5',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 8,
#      'blocks': 1,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 12,
#      'fieldGoalsMade': 7,
#      'fieldGoalsPercentage': 0.583333333333333,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 4,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 1,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 1.0,
#      'minus': 32.0,
#      'minutes': 'PT21M06.00S',
#      'minutesCalculated': 'PT21M',
#      'plus': 52.0,
#      'plusMinusPoints': 20.0,
#      'points': 17,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 10,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 1,
#      'threePointersAttempted': 4,
#      'threePointersMade': 2,
#      'threePointersPercentage': 0.5,
#      'turnovers': 2,
#      'twoPointersAttempted': 8,
#      'twoPointersMade': 5,
#      'twoPointersPercentage': 0.625},
#     'name': 'Immanuel Quickley',
#     'nameI': 'I. Quickley',
#     'firstName': 'Immanuel',
#     'familyName': 'Quickley'},
#    {'status': 'ACTIVE',
#     'order': 9,
#     'personId': 1630167,
#     'jerseyNum': '1',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 1,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 8,
#      'fieldGoalsMade': 5,
#      'fieldGoalsPercentage': 0.625,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 32.0,
#      'minutes': 'PT16M57.00S',
#      'minutesCalculated': 'PT17M',
#      'plus': 33.0,
#      'plusMinusPoints': 1.0,
#      'points': 12,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 6,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 5,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 5,
#      'steals': 1,
#      'threePointersAttempted': 4,
#      'threePointersMade': 2,
#      'threePointersPercentage': 0.5,
#      'turnovers': 1,
#      'twoPointersAttempted': 4,
#      'twoPointersMade': 3,
#      'twoPointersPercentage': 0.75},
#     'name': 'Obi Toppin',
#     'nameI': 'O. Toppin',
#     'firstName': 'Obi',
#     'familyName': 'Toppin'},
#    {'status': 'ACTIVE',
#     'order': 10,
#     'personId': 1628995,
#     'jerseyNum': '20',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 3,
#      'fieldGoalsMade': 1,
#      'fieldGoalsPercentage': 0.333333333333333,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 3,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 27.0,
#      'minutes': 'PT15M29.00S',
#      'minutesCalculated': 'PT16M',
#      'plus': 30.0,
#      'plusMinusPoints': 3.0,
#      'points': 3,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 2,
#      'steals': 0,
#      'threePointersAttempted': 2,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.5,
#      'turnovers': 0,
#      'twoPointersAttempted': 1,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Kevin Knox II',
#     'nameI': 'K. Knox II',
#     'firstName': 'Kevin',
#     'familyName': 'Knox II'},
#    {'status': 'ACTIVE',
#     'order': 11,
#     'personId': 1628372,
#     'jerseyNum': '4',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 2,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 0.5,
#      'minus': 9.0,
#      'minutes': 'PT03M44.00S',
#      'minutesCalculated': 'PT04M',
#      'plus': 4.0,
#      'plusMinusPoints': -5.0,
#      'points': 1,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 1,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Dennis Smith Jr.',
#     'nameI': 'D. Smith Jr.',
#     'firstName': 'Dennis',
#     'familyName': 'Smith Jr.'},
#    {'status': 'ACTIVE',
#     'order': 12,
#     'personId': 1629033,
#     'jerseyNum': '21',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 1,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 9.0,
#      'minutes': 'PT03M31.00S',
#      'minutesCalculated': 'PT04M',
#      'plus': 3.0,
#      'plusMinusPoints': -6.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Theo Pinson',
#     'nameI': 'T. Pinson',
#     'firstName': 'Theo',
#     'familyName': 'Pinson'},
#    {'status': 'ACTIVE',
#     'order': 13,
#     'personId': 1629649,
#     'jerseyNum': '17',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 8.0,
#      'minutes': 'PT03M17.00S',
#      'minutesCalculated': 'PT03M',
#      'plus': 3.0,
#      'plusMinusPoints': -5.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 1,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Ignas Brazdeikis',
#     'nameI': 'I. Brazdeikis',
#     'firstName': 'Ignas',
#     'familyName': 'Brazdeikis'},
#    {'status': 'ACTIVE',
#     'order': 14,
#     'personId': 201959,
#     'jerseyNum': '67',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Taj Gibson',
#     'nameI': 'T. Gibson',
#     'firstName': 'Taj',
#     'familyName': 'Gibson'},
#    {'status': 'ACTIVE',
#     'order': 15,
#     'personId': 1629607,
#     'jerseyNum': '0',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Jared Harper',
#     'nameI': 'J. Harper',
#     'firstName': 'Jared',
#     'familyName': 'Harper'},
#    {'status': 'INACTIVE',
#     'notPlayingReason': 'INACTIVE_INJURY',
#     'notPlayingDescription': 'Left Ankle; sprained',
#     'order': 16,
#     'personId': 202692,
#     'jerseyNum': '18',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Alec Burks',
#     'nameI': 'A. Burks',
#     'firstName': 'Alec',
#     'familyName': 'Burks'},
#    {'status': 'INACTIVE',
#     'notPlayingReason': 'INACTIVE_INJURY',
#     'notPlayingDescription': 'Right Knee; sprained',
#     'order': 17,
#     'personId': 1628373,
#     'jerseyNum': '11',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Frank Ntilikina',
#     'nameI': 'F. Ntilikina',
#     'firstName': 'Frank',
#     'familyName': 'Ntilikina'}],
#   'statistics': {'assists': 22,
#    'assistsTurnoverRatio': 1.29411764705882,
#    'benchPoints': 38,
#    'biggestLead': 37,
#    'biggestLeadScore': '101-64',
#    'biggestScoringRun': 12,
#    'biggestScoringRunScore': '101-64',
#    'blocks': 7,
#    'blocksReceived': 2,
#    'fastBreakPointsAttempted': 3,
#    'fastBreakPointsMade': 2,
#    'fastBreakPointsPercentage': 0.666666666666666,
#    'fieldGoalsAttempted': 80,
#    'fieldGoalsEffectiveAdjusted': 0.55,
#    'fieldGoalsMade': 38,
#    'fieldGoalsPercentage': 0.475,
#    'foulsOffensive': 3,
#    'foulsDrawn': 22,
#    'foulsPersonal': 28,
#    'foulsTeam': 25,
#    'foulsTechnical': 0,
#    'foulsTeamTechnical': 0,
#    'freeThrowsAttempted': 21,
#    'freeThrowsMade': 17,
#    'freeThrowsPercentage': 0.8095238095238101,
#    'leadChanges': 0,
#    'minutes': 'PT240M00.00S',
#    'minutesCalculated': 'PT240M',
#    'points': 105,
#    'pointsAgainst': 75,
#    'pointsFastBreak': 7,
#    'pointsFromTurnovers': 22,
#    'pointsInThePaint': 48,
#    'pointsInThePaintAttempted': 41,
#    'pointsInThePaintMade': 24,
#    'pointsInThePaintPercentage': 0.585365853658536,
#    'pointsSecondChance': 17,
#    'reboundsDefensive': 43,
#    'reboundsOffensive': 10,
#    'reboundsPersonal': 53,
#    'reboundsTeam': 10,
#    'reboundsTeamDefensive': 6,
#    'reboundsTeamOffensive': 4,
#    'reboundsTotal': 63,
#    'secondChancePointsAttempted': 7,
#    'secondChancePointsMade': 5,
#    'secondChancePointsPercentage': 0.714285714285714,
#    'steals': 11,
#    'threePointersAttempted': 31,
#    'threePointersMade': 12,
#    'threePointersPercentage': 0.387096774193548,
#    'timeLeading': 'PT46M30.00S',
#    'timesTied': 1,
#    'trueShootingAttempts': 89.24,
#    'trueShootingPercentage': 0.588301210219632,
#    'turnovers': 16,
#    'turnoversTeam': 1,
#    'turnoversTotal': 17,
#    'twoPointersAttempted': 49,
#    'twoPointersMade': 26,
#    'twoPointersPercentage': 0.530612244897959}}}

# %%
# Getting Box Scores.
# Note: home_team & away_team have the identical data structure
players = box.away_team.get_dict()['players']
f = "{player_id}: {name}: {points} PTS"
for player in players:
  print(f.format(player_id=player['personId'],name=player['name'],points=player['statistics']['points']))
# Out:
# 203493: Reggie Bullock: 11 PTS
# 203944: Julius Randle: 20 PTS
# 1629011: Mitchell Robinson: 8 PTS
# 1629628: RJ Barrett: 19 PTS
# 203901: Elfrid Payton: 9 PTS
# 203457: Nerlens Noel: 5 PTS
# 203085: Austin Rivers: 0 PTS
# 1630193: Immanuel Quickley: 17 PTS
# 1630167: Obi Toppin: 12 PTS
# 1628995: Kevin Knox II: 3 PTS
# 1628372: Dennis Smith Jr.: 1 PTS
# 1629033: Theo Pinson: 0 PTS
# 1629649: Ignas Brazdeikis: 0 PTS
# 201959: Taj Gibson: 0 PTS
# 1629607: Jared Harper: 0 PTS
# 202692: Alec Burks: 0 PTS
# 1628373: Frank Ntilikina: 0 PTS

# %% [markdown]
# ## Play By Play Data

# %%
# Query nba.live.endpoints for the score board of GameID 0022000180 = NYK vs BOS
# Simple PlayByPlay Loop demonstrating data usage
from nba_api.live.nba.endpoints import playbyplay
from nba_api.stats.static import players

pbp = playbyplay.PlayByPlay('0022000180')
line = "{action_number}: {period}:{clock} {player_id} ({action_type})"
actions = pbp.get_dict()['game']['actions'] #plays are referred to in the live data as `actions`

for action in actions:
  player_name = ''
  player = players.find_player_by_id(action['personId'])
  if player is not None:
    player_name = player['full_name']
  print(line.format(action_number=action['actionNumber'], period=action['period'], clock=action['clock'],action_type=action['actionType'],player_id=player_name))
# Out:
# 2: 1:PT12M00.00S  (period)
# 4: 1:PT11M58.00S Grant Williams (jumpball)
# 7: 1:PT11M46.00S Jeff Teague (3pt)
# 9: 1:PT11M18.00S  (turnover)
# 10: 1:PT11M05.00S Jaylen Brown (2pt)
# 11: 1:PT11M03.00S Cole Anthony (rebound)
# 12: 1:PT10M53.00S Nikola Vucevic (2pt)
# 14: 1:PT10M39.00S Jeff Teague (3pt)
# 15: 1:PT10M36.00S Dwayne Bacon (rebound)
# 16: 1:PT10M29.00S Dwayne Bacon (2pt)
# 17: 1:PT10M14.00S Jeff Teague (2pt)
# 18: 1:PT09M48.00S Nikola Vucevic (3pt)
# 19: 1:PT09M45.00S Marcus Smart (rebound)
# 20: 1:PT09M26.00S Tristan Thompson (2pt)
# 21: 1:PT09M13.00S Nikola Vucevic (foul)
# 23: 1:PT09M13.00S Nikola Vucevic (turnover)
# 24: 1:PT08M59.00S Jaylen Brown (2pt)
# 25: 1:PT08M38.00S Cole Anthony (2pt)
# 26: 1:PT08M20.00S Marcus Smart (2pt)
# 27: 1:PT08M17.00S  (rebound)
# 28: 1:PT08M17.00S  (stoppage)
# 29: 1:PT08M07.00S Cole Anthony (turnover)
# 30: 1:PT08M07.00S Tristan Thompson (steal)
# 31: 1:PT08M00.00S Marcus Smart (2pt)
# 32: 1:PT07M44.00S Cole Anthony (turnover)
# 33: 1:PT07M44.00S Jaylen Brown (steal)
# 34: 1:PT07M43.00S Jaylen Brown (2pt)
# 35: 1:PT07M43.00S  (timeout)
# 36: 1:PT07M22.00S Cole Anthony (3pt)
# 38: 1:PT07M03.00S Marcus Smart (3pt)
# 39: 1:PT07M02.00S Dwayne Bacon (rebound)
# 40: 1:PT06M55.00S Dwayne Bacon (2pt)
# 41: 1:PT06M55.00S Dwayne Bacon (rebound)
# 42: 1:PT06M47.00S Dwayne Bacon (2pt)
# 43: 1:PT06M38.00S Grant Williams (2pt)
# 44: 1:PT06M31.00S Tristan Thompson (rebound)
# 45: 1:PT06M31.00S Tristan Thompson (2pt)
# 46: 1:PT06M30.00S Nikola Vucevic (rebound)
# 47: 1:PT06M26.00S Dwayne Bacon (2pt)
# 48: 1:PT06M22.00S Tristan Thompson (rebound)
# 49: 1:PT06M20.00S Jaylen Brown (2pt)
# 50: 1:PT06M20.00S James Ennis III (foul)
# 52: 1:PT06M20.00S Aaron Gordon (substitution)
# 53: 1:PT06M20.00S Khem Birch (substitution)
# 54: 1:PT06M20.00S Jaylen Brown (freethrow)
# 56: 1:PT06M01.00S Cole Anthony (2pt)
# 58: 1:PT05M51.00S Cole Anthony (foul)
